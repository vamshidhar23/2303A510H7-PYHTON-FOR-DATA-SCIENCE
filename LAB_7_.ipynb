# %% [markdown]
# <a href="https://colab.research.google.com/github/vamshidhar23/2303A510H7-PYHTON-FOR-DATA-SCIENCE/blob/main/LAB_7_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PART!!! 1**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("daily_temperature.csv")

# %%
print(data.head())
# Out:
#    Day  Temperature
# 0    1           26
# 1    2           34
# 2    3           30
# 3    4           27
# 4    5           26

# %%
plt.figure(figsize=(10,6))
plt.plot(
    data["Day"],
    data["Temperature"],
    marker='o',
    linestyle='-',
    color='b',
    label="Temperature"
)

plt.xlabel("Day of the Month")
plt.ylabel("Temperature (°C)")
plt.title("Daily Temperature Changes Over a Month")
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()

plt.show()

# %% [markdown]
# # **Part - 2**

# %%
data = pd.read_csv("sales_data.csv")

# %%
plt.figure(figsize=(8,5))
plt.plot(
    data["Quarter"],
    data["Sales"],
    marker='o',
    linestyle='-',
    color='b',
    label="Sales"
)

peak = data.loc[data["Sales"].idxmax()]
plt.scatter(peak["Quarter"], peak["Sales"], color='red', s=100, zorder=5, label="Peak Sales")

plt.xlabel("Quarter")
plt.ylabel("Sales ($)")
plt.title("Quarterly Sales Performance")
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()

plt.show()

# %%
print(f"Peak Sales: {peak['Quarter']} with ${peak['Sales']}")
# Out:
# Peak Sales: Q4 with $30000
